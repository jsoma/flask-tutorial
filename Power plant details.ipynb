# %%
import pandas as pd
pd.options.display.max_columns = None

df = pd.read_csv("powerplants.csv")
df.head()
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
# 3           7             Gadsden  Alabama Power Co         195
# 4           8              Gorgas  Alabama Power Co         195
#
#          sector_nam       City      County StateName    Zip  \
# 0  Electric Utility  Northport  Tuscaloosa   Alabama  35476
# 1  Electric Utility      Bucks      Mobile   Alabama  36512
# 2  Electric Utility   Wetumpka      Elmore   Alabama  36092
# 3  Electric Utility    Gadsden      Etowah   Alabama  35903
# 4  Electric Utility    Parrish      Walker   Alabama  35580
#
#              Street_Add     PrimSource  Install_MW  Total_MW  Coal_MW   NG_MW  \
# 0    19001 Lock 17 Road  hydroelectric        53.9      56.0      0.0     0.0
# ...

# %%
powerplants = df.to_dict('records')
powerplants[:5]
# Out:
# [{'Plant_Code': 2,
#   'Plant_Name': 'Bankhead Dam',
#   'Utility_Na': 'Alabama Power Co',
#   'Utility_ID': 195,
#   'sector_nam': 'Electric Utility',
#   'City': 'Northport',
#   'County': 'Tuscaloosa',
#   'StateName': 'Alabama',
#   'Zip': 35476,
#   'Street_Add': '19001 Lock 17 Road',
#   'PrimSource': 'hydroelectric',
#   'Install_MW': 53.9,
#   'Total_MW': 56.0,
#   'Coal_MW': 0.0,
#   'NG_MW': 0.0,
#   'Crude_MW': 0.0,
#   'Bio_MW': nan,
#   'Hydro_MW': 56.0,
#   'HydroPS_MW': 0.0,
#   'Nuclear_MW': 0.0,
#   'Solar_MW': 0.0,
#   'Wind_MW': 0.0,
#   'Geo_MW': nan,
#   'Other_MW': 0.0,
#   'source_des': 'Hydroelectric = 56 MW',
#   'tech_desc': 'Conventional Hydroelectric',
#   'Source': 'EIA-860, EIA-860M and EIA-923',
#   'Period': 201801,
#   'Latitude': 33.458665,
#   'Longitude': -87.356823},
#  {'Plant_Code': 3,
#   'Plant_Name': 'Barry',
#   'Utility_Na': 'Alabama Power Co',
#   'Utility_ID': 195,
#   'sector_nam': 'Electric Utility',
#   'City': 'Bucks',
# ...
